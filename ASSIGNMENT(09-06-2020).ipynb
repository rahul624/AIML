# %% [markdown]
# ## CSE_221710306050-RAHUL.k

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### QUESTION-1

# %%
df=pd.read_csv("https://raw.githubusercontent.com/kotagiri-preeti/Summer-Internship-AI-and-ML/master/Match%20(1).csv")
data1 = df["ManOfMach"].value_counts().rename_axis('players').reset_index(name='no.of ManOfMach')
data2 = data1.sort_values(by=['players'],ascending=True,ignore_index=True)
data2.head(29)
# Out:
#             players  no.of ManOfMach
# 0        A Chandila                1
# 1          A Kumble                3
# 2          A Mishra                9
# 3           A Nehra                6
# 4           A Singh                1
# 5         A Symonds                3
# 6           A Zampa                1
# 7   AA Jhunjhunwala                1
# 8          AB Dinda                2
# 9    AB de Villiers               15
# 10     AC Gilchrist                7
# 11         AC Voges                1
# 12   AD Mascarenhas                1
# 13       AD Mathews                1
# 14       AD Russell                6
# 15         AJ Finch                5
# 16           AJ Tye                2
# 17        AM Rahane               12
# 18          AP Tare                1
# 19         AR Patel                4
# 20        AT Rayudu                7
# 21    Azhar Mahmood                2
# 22          B Kumar                5
# 23            B Lee                2
# 24         BA Bhatt                1
# 25        BA Stokes                3
# 26      BB McCullum                5
# 27      BCJ Cutting                1
# 28         BJ Hodge                6

# %% [markdown]
# ### QUESTION-2

# %%
df["Country_Name"].value_counts()[:10].plot(kind="pie",
                                            colors=["blue","green","red"],
                                            autopct="%0.1f%%",
                                            explode=[0.2,0,0],
                                            startangle = 40,radius=1.5)
